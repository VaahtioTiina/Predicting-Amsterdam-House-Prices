# %% [markdown]
# # Data Prep - Amsterdam Open Data -  Predicting Housing Prices

# %% [markdown]
# In this notebook we prepare and join data retrieved as csv-files from Amsterdam Open Data. We have lot's of information about the different neighborhoods in the city such as "safety index", "crime index", % of people with certain income levels etc.

# %%
# Import libraries
import pandas as pd
import re

# %%
# Read excelfiles

xl = pd.ExcelFile(r'C:\Users\tiina\Downloads\buurt_info3.xlsx')
xl.sheet_names
# read a specific sheet to DataFrame
safety = xl.parse('VI_heel 2019')

# %%
safety.head()
# Out:
#   VM14gebiednaam afgekort VM14gebiednummer  VM14 gebiedsnaam voluit  \
# 0            vmgebiednaam     vmgebied16nr                      NaN
# 1                     A00                1    Burgwallen-Oude Zijde
# 2                     A01                2  Burgwallen-Nieuwe Zijde
# 3                     A02                3      Grachtengordel-West
# 4                     A03                4      Grachtengordel-Zuid
#
#   totale veiligheidsindex  \
# 0        veiligheidsindex
# 1                   178.1
# 2                  168.84
# 3                   79.61
# 4                  137.45
#
#   index gemiddelde inschatting (ontwikkeling) buurtcriminaliteit en -overlast  \
# 0                               ipsl_risicoperceptie
# 1                                             136.67
# 2                                             122.61
# 3                                             110.42
# 4                                             112.97
#
#   index gemiddelde score onveiligheids-gevoelens buurt  \
# 0                        ipsl_onveiligheidsgevoelens
# 1                                              99.27
# 2                                              94.46
# 3                                              52.24
# 4                                               65.4
#
#   index gemiddelde score vermijding plekken en situaties in buurt  \
# 0                                    ipsl_vermijding
# 1                                              84.26
# 2                                              73.79
# 3                                              45.99
# 4                                              45.37
#
#   totale index onveiligheids-beleving deelindex overlast: personenoverlast  \
# 0          Onveiligheidsbelevingindex                    Ipersonenoverlast
# 1                              106.73                               507.91
# 2                               96.95                               453.97
# 3                               69.55                               132.56
# 4                               74.58                                268.8
#
#   deelindex overlast: verloedering  ... populatie per 1-1-2017  \
# 0                    Iverloedering  ...                    pop
# 1                           143.21  ...                   4293
# 2                            130.8  ...                   4130
# 3                           100.52  ...                   6374
# 4                           127.85  ...                   5383
#
#   aantal woningen per 1-1-2017 aantal winkels per  1-1-2017  \
# 0                     nwoninge                        nwink
# 1                         2917                          222
# 2                         2884                          594
# 3                         4314                          245
# 4                         3449                          177
#
#   aantal bedrijven (niet-winkels) per  1-1-2017  aantal werkzame personen  \
# 0                                         nbedr                  werkpers
# 1                                          1934                      6233
# 2                                          2350                      9428
# 3                                          3043                      6989
# 4                                          1799                      6350
#
#   aantal studenten (VO, HBO en WO) aantal bezoekers op een gemiddelde dag  \
# 0                          student                                 bezoek
# 1                             1746                                  80626
# 2                             1689                                 139692
# 3                                0                                  43940
# 4                                0                                  29459
#
#   som werkzame personen, studenten en bezoekers  \
# 0                                       nbezoek
# 1                                         88605
# 2                                        150809
# 3                                         50929
# 4                                         35809
#
#   aantal verblijvers in een buurt waarbij nbezoek voor 1/3 meetelt  \
# 0                                           verbtot3
# 1                                              33828
# 2                                            54399.7
# 3                                            23350.3
# 4                                            17319.3
#
#   aantal verblijvers in een buurt waarbij werkzame personen voor 1/3 en andere bezoekers voor 1/8 meetellen
# 0                                          verbnieuw
# 1                                            16667.2
# 2                                            24945.3
# 3                                            14196.2
# 4                                              11182
#
# [5 rows x 186 columns]

# %%
# Clean up some messy rows to get the data right
safety = safety[safety['VM14gebiednaam afgekort'] != 'vmgebiednaam']

# %%
# Read income dataset

xl = pd.ExcelFile(r'C:\Users\tiina\Downloads\income staadsdelen.xlsx')

xl.sheet_names

# read a specific sheet to DataFrame
income = xl.parse('2020_stadsdelen_3.18')

# %%
income.head(60)
# Out:
#    3.18a   Personen met inkomen in particuliere huishoudens (incl. studenten) (x 1.000) naar inkomensklassen  \
# 0                (20%-groepen van de landelijke ve...
# 1                                                 NaN
# 2                                                 NaN
# 3                                            wijk/std
# 4                                                 NaN
# 5                                                 A00
# 6                                                 A01
# 7                                                 A02
# 8                                                 A03
# 9                                                 A04
# 10                                                A05
# 11                                                A06
# 12                                                A07
# 13                                                A08
# 14                                                A09
# 15                                                  A
# 16                                                NaN
# 17                                                B10
# 18                                                  B
# 19                                                NaN
# 20                                                E12
# 21                                                E13
# 22                                                E14
# 23                                                E15
# 24                                                E16
# 25                                                E17
# 26                                                E18
# 27                                                E19
# 28                                                E20
# 29                                                E21
# 30                                                E22
# 31                                                E36
# 32                                                E37
# 33                                                E38
# 34                                                E39
# 35                                                E40
# 36                                                E41
# 37                                                E42
# 38                                                E43
# 39                                                E75
# 40                                                  E
# 41                                                NaN
# 42                                                F11
# 43                                                F76
# 44                                                F77
# 45                                                F78
# 46                                                F79
# 47                                                F80
# 48                                                F81
# 49                                                F82
# 50                                                F83
# 51                                                F84
# 52                                                F85
# 53                                                F86
# 54                                                F87
# 55                                                F88
# 56                                                F89
# 57                                                  F
# 58                                                NaN
# 59  3.18a   Personen met inkomen in particuliere h...
#
#                          Unnamed: 1   Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0                               NaN          NaN           NaN           NaN
# 1                               NaN          NaN           NaN           NaN
# 2                               NaN   minder dan  11.100 euro-  20.000 euro-
# 3                     naam wijk/std  11.100 euro  <20.000 euro  <31.200 euro
# 4                               NaN          NaN           NaN           NaN
# 5             Burgwallen-Oude Zijde          0.8           0.7           0.7
# 6           Burgwallen-Nieuwe Zijde          0.6           0.6           0.6
# 7               Grachtengordel-West            1           0.6           0.6
# 8               Grachtengordel-Zuid          0.8           0.5           0.6
# 9                Nieuwmarkt/Lastage          1.4           1.5           1.3
# 10                  Haarlemmerbuurt          1.2           1.5           1.2
# 11                          Jordaan          2.8           3.4           2.8
# 12                De Weteringschans            1           0.8           0.8
# 13            Weesperbuurt/Plantage            1             1           0.9
# 14     Oostelijke Eilanden/Kadijken            2           2.3           1.7
# 15                          Centrum         12.4          12.9          11.1
# 16                              NaN          NaN           NaN           NaN
# 17            Westelijk Havengebied            x             x             x
# 18                        Westpoort            x             x             x
# 19                              NaN          NaN           NaN           NaN
# 20                       Houthavens          0.1           0.1           0.1
# 21  Spaarndammer- en Zeeheldenbuurt          1.4           2.2           1.6
# 22                Staatsliedenbuurt          1.8           2.3           1.9
# 23                   Centrale Markt          0.4           0.3           0.3
# 24            Frederik Hendrikbuurt            1           1.4           1.1
# 25                    Da Costabuurt          0.6           0.7           0.6
# 26                      Kinkerbuurt          0.8             1           0.9
# 27                  Van Lennepbuurt            1           1.5           1.1
# 28                     Helmersbuurt            1           0.9           0.8
# 29                 Overtoomse Sluis          0.8           1.1           0.9
# 30                      Vondelbuurt          0.3           0.2           0.2
# 31                       Sloterdijk            x             x             x
# 32                         Landlust          2.9           3.4           2.6
# 33                      Erasmuspark          0.8           0.8           0.9
# 34                      De Kolenkit          1.9           1.7           1.4
# 35                      Geuzenbuurt          0.9             1             1
# 36                   Van Galenbuurt          0.8           1.2           0.8
# 37                    Hoofdweg e.o.          1.4             2           1.5
# 38               Westindische Buurt          0.8           0.9             1
# 39                      Chassébuurt            1             1           0.9
# 40                             West         19.8          23.7          19.6
# 41                              NaN          NaN           NaN           NaN
# 42      Bedrijventerrein Sloterdijk          0.1           0.1           0.1
# 43             Slotermeer-Noordoost          1.6           1.9           1.5
# 44              Slotermeer-Zuidwest          3.2           3.7           2.8
# 45                       Geuzenveld          2.7           2.8           2.5
# 46                        Eendracht          0.3           0.4           0.4
# 47                Lutkemeer/Ookmeer          0.1           0.2           0.1
# 48                      Osdorp-Oost          2.7           3.2           2.8
# 49                    Osdorp-Midden          2.6           2.8           2.3
# 50                          De Punt          0.9           1.1             1
# 51        Middelveldsche Akerpolder          2.4           1.8             2
# 52                Slotervaart-Noord          1.3           1.3           1.2
# 53                  Overtoomse Veld          2.5           1.8           1.7
# 54                   Westlandgracht          1.6           1.5           1.2
# 55             Sloter-/Riekerpolder          2.1           1.7             2
# 56                 Slotervaart-Zuid            2           1.8           1.6
# 57                       Nieuw-West         26.4          26.1          23.3
# 58                              NaN          NaN           NaN           NaN
# 59                              NaN          NaN           NaN           NaN
#
#       Unnamed: 5   Unnamed: 6 Unnamed: 7
# 0            NaN          NaN        NaN
# 1            NaN          NaN        NaN
# 2   31.200 euro-  46.800 euro        NaN
# 3   <46.800 euro      en meer     totaal
# 4            NaN          NaN        NaN
# 5            0.7          0.9        3.7
# 6            0.7          0.9        3.4
# 7            0.9          2.1        5.2
# 8            0.8          1.7        4.3
# 9            1.5          2.4        8.1
# 10           1.3          2.4        7.6
# 11           3.1          4.6       16.6
# 12           1.1          2.2          6
# 13           1.1            2          6
# 14           2.1          2.8       10.9
# 15          13.4           22       71.9
# 16           NaN          NaN        NaN
# 17             x            x        0.2
# 18             x            x        0.2
# 19           NaN          NaN        NaN
# 20           0.2          0.4        0.9
# 21           1.8          1.8        8.8
# 22           2.3          3.1       11.2
# 23           0.4          0.6          2
# 24           1.4            2        6.9
# 25           0.8          1.3          4
# 26           1.1          1.5        5.3
# 27           1.1          1.4          6
# 28           1.2          2.2        6.1
# 29           1.3          2.4        6.5
# 30           0.2          0.5        1.4
# 31             x            x        0.4
# 32             3          2.9       14.8
# 33           1.1          1.3        4.9
# 34           1.3          1.1        7.5
# 35           1.2          1.6        5.8
# 36             1          0.9        4.7
# 37           1.8          1.8        8.5
# 38           1.2          1.8        5.8
# 39           0.9          1.2          5
# 40          23.3         29.9      116.4
# 41           NaN          NaN        NaN
# 42           0.1            0        0.5
# 43           1.2          0.7        6.8
# 44           2.2          1.5       13.4
# 45           1.9          1.3       11.2
# 46           0.4          0.3        1.9
# 47           0.1          0.2        0.7
# 48           2.2          1.8       12.8
# 49             2          1.7       11.4
# 50           0.8          0.5        4.5
# 51           2.2          2.8       11.2
# 52           1.1          1.1        5.9
# 53           2.1          1.8        9.9
# 54           1.4            2        7.8
# 55           2.3          3.1       11.2
# 56           1.4          1.1        7.9
# 57          21.4         19.9        117
# 58           NaN          NaN        NaN
# 59           NaN          NaN        NaN

# %%
# Rename columns and translate to english

column_names = ['neighborhood', 'income_low', 'income_med_low', 'income_med', 'income_med_high', 'ingome_high', 'total']

# %%
# Drop unnecessary column
income.drop(columns={'3.18a   Personen met inkomen in particuliere huishoudens (incl. studenten) (x 1.000) naar inkomensklassen'},inplace=True)

# %%
income.columns
# Out:
# Index(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
# Drop null values
income.dropna(inplace=True)

# %%
# Assign new columns
income.columns = column_names

# %%
# remove messy rows
income = income[income.neighborhood != 'naam wijk/std']

# %%
# Calculate percentage of people at certain income level
for col in income.columns:
    if col != 'neighborhood':
        income[col] = pd.to_numeric(income[col], errors='coerce')
        income[col] = income[col]/income['total']

# %%
# See the unique values for different neighborhoods
income.neighborhood.unique()

# %%
# Read the houses dataset - so we can start combining data
houses = pd.read_csv('houses_coordinates.csv')

# %% [markdown]
# ## Building keys to join data from different datasets

# %% [markdown]
# In this project  I have data coming from different sources, and with that also comes many variants of naming etc. I will use two datasets from CBS to first combine data with postalcodes, and then retrieving the neighborhood names, which will then naturally be unified accross the dataset.

# %%
# Read postcode data
post_code_statsdel = pd.read_csv(r'C:\Users\tiina\Downloads\2019-cbs-pc6huisnr20190801_buurt\pc6hnr20190801_gwb.csv', sep=";")

# %%
# Read neighborhood names
stads_del = pd.read_csv(r'C:\Users\tiina\Downloads\2019-cbs-pc6huisnr20190801_buurt\wijk2019.csv', sep=";")

# %%
# Drop duplicate values - data was on a more granural level than postcodes
post_wijken = post_code_statsdel.drop_duplicates(subset=['PC6'])

# %%
# Merge datasets together to retrieve the name
post_wijken = post_wijken.merge(stads_del, how='left', left_on='Wijk2019', right_on='Wijkcode2019')

# %%
# Filter only Amsterdam with code 363
post_wijken = post_wijken[post_wijken['Gemeente2019']==363]
post_wijken.head()
# Out:
#       PC6  Huisnummer  Buurt2019  Wijk2019  Gemeente2019  Wijkcode2019  \
# 0  1011AB         105    3630400     36304           363         36304
# 1  1011AC         125    3630400     36304           363         36304
# 2  1011AD           1    3630400     36304           363         36304
# 3  1011AE           8    3630400     36304           363         36304
# 4  1011AG          96    3630403     36304           363         36304
#
#   Wijknaam_2019K_NAAM
# 0  Nieuwmarkt/Lastage
# 1  Nieuwmarkt/Lastage
# 2  Nieuwmarkt/Lastage
# 3  Nieuwmarkt/Lastage
# 4  Nieuwmarkt/Lastage

# %%
# Drop unnecessary columns
post_wijken = post_wiken.drop(columns={'Huisnummer', 'Buurt2019', 'Gemeente2019', 'Wijkcode2019'})

# %%
# Clean neighborhood names
post_wijken['Wijknaam_2019K_NAAM'] = post_wijken.Wijknaam_2019K_NAAM.apply(lambda x: re.sub('-', ' ', x))

# %%
# Compare neighborhood names 
sorted(post_wijken.Wijknaam_2019K_NAAM.unique())
# Out:
# ['Amstel III/Bullewijk',
#  'Apollobuurt',
#  'Banne Buiksloot',
#  'Bedrijventerrein Sloterdijk',
#  'Betondorp',
#  'Bijlmer Centrum (D,F,H)',
#  'Bijlmer Oost (E,G,K)',
#  'Buikslotermeer',
#  'Buitenveldert Oost',
#  'Buitenveldert West',
#  'Burgwallen Nieuwe Zijde',
#  'Burgwallen Oude Zijde',
#  'Centrale Markt',
#  'Chassébuurt',
#  'Da Costabuurt',
#  'Dapperbuurt',
#  'De Kolenkit',
#  'De Punt',
#  'De Weteringschans',
#  'Driemond',
#  'Eendracht',
#  'Elzenhagen',
#  'Erasmuspark',
#  'Frankendael',
#  'Frederik Hendrikbuurt',
#  'Gein',
#  'Geuzenbuurt',
#  'Geuzenveld',
#  'Grachtengordel West',
#  'Grachtengordel Zuid',
#  'Haarlemmerbuurt',
#  'Helmersbuurt',
#  'Holendrecht/Reigersbos',
#  'Hoofddorppleinbuurt',
#  'Hoofdweg e.o.',
#  'Houthavens',
#  'IJburg Oost',
#  'IJburg West',
#  'IJburg Zuid',
#  'IJplein/Vogelbuurt',
#  'IJselbuurt',
#  'Indische Buurt Oost',
#  'Indische Buurt West',
#  'Jordaan',
#  'Kadoelen',
#  'Kinkerbuurt',
#  'Landlust',
#  'Lutkemeer/Ookmeer',
#  'Middelveldsche Akerpolder',
#  'Middenmeer',
#  'Museumkwartier',
#  'Nellestein',
#  'Nieuwe Pijp',
#  'Nieuwendammerdijk/Buiksloterdijk',
#  'Nieuwmarkt/Lastage',
#  'Noordelijke IJ oevers Oost',
#  'Noordelijke IJ oevers West',
#  'Omval/Overamstel',
#  'Oostelijk Havengebied',
#  'Oostelijke Eilanden/Kadijken',
#  'Oosterparkbuurt',
#  'Oostzanerwerf',
#  'Osdorp Midden',
#  'Osdorp Oost',
#  'Oude Pijp',
#  'Overtoomse Sluis',
#  'Overtoomse Veld',
#  'Prinses Irenebuurt e.o.',
#  'Rijnbuurt',
#  'Scheldebuurt',
#  'Schinkelbuurt',
#  'Sloter /Riekerpolder',
#  'Sloterdijk',
#  'Slotermeer Noordoost',
#  'Slotermeer Zuidwest',
#  'Slotervaart Noord',
#  'Slotervaart Zuid',
#  'Spaarndammer  en Zeeheldenbuurt',
#  'Staatsliedenbuurt',
#  'Stadionbuurt',
#  'Transvaalbuurt',
#  'Tuindorp Buiksloot',
#  'Tuindorp Nieuwendam',
#  'Tuindorp Oostzaan',
#  'Van Galenbuurt',
#  'Van Lennepbuurt',
#  'Volewijck',
#  'Vondelbuurt',
#  'Waterland',
#  'Waterlandpleinbuurt',
#  'Weesperbuurt/Plantage',
#  'Weesperzijde',
#  'Westelijk Havengebied',
#  'Westindische Buurt',
#  'Westlandgracht',
#  'Willemspark',
#  'Zeeburgereiland/Nieuwe Diep',
#  'Zuid Pijp',
#  'Zuidas']

# %%
# Identifying neighborhood values that don't match our neighborhood names
not_found = []
for wijk in income.neighborhood:
    if re.sub('-', ' ', wijk)not in post_wijken.Wijknaam_2019K_NAAM.unique():
        not_found.append(wijk)

# %%
len(not_found)
# Out:
# 10

# %%
print(not_found)
# Out:
# ['Centrum', 'Westpoort', 'West', 'Nieuw-West', 'Zuid', 'De Omval/Overamstel', 'Oost', 'Noord', 'Zuidoost', 'Amsterdam']

# %%
# modify:
sorted(income.neighborhood.unique())
# Out:
# ['Amstel III/Bullewijk',
#  'Amsterdam',
#  'Apollobuurt',
#  'Banne Buiksloot',
#  'Bedrijventerrein Sloterdijk',
#  'Betondorp',
#  'Bijlmer-Centrum (D,F,H)',
#  'Bijlmer-Oost (E,G,K)',
#  'Buikslotermeer',
#  'Buitenveldert-Oost',
#  'Buitenveldert-West',
#  'Burgwallen-Nieuwe Zijde',
#  'Burgwallen-Oude Zijde',
#  'Centrale Markt',
#  'Centrum',
#  'Chassébuurt',
#  'Da Costabuurt',
#  'Dapperbuurt',
#  'De Kolenkit',
#  'De Omval/Overamstel',
#  'De Punt',
#  'De Weteringschans',
#  'Driemond',
#  'Eendracht',
#  'Elzenhagen',
#  'Erasmuspark',
#  'Frankendael',
#  'Frederik Hendrikbuurt',
#  'Gein',
#  'Geuzenbuurt',
#  'Geuzenveld',
#  'Grachtengordel-West',
#  'Grachtengordel-Zuid',
#  'Haarlemmerbuurt',
#  'Helmersbuurt',
#  'Holendrecht/Reigersbos',
#  'Hoofddorppleinbuurt',
#  'Hoofdweg e.o.',
#  'Houthavens',
#  'IJburg-Oost',
#  'IJburg-West',
#  'IJburg-Zuid',
#  'IJplein/Vogelbuurt',
#  'IJselbuurt',
#  'Indische Buurt-Oost',
#  'Indische Buurt-West',
#  'Jordaan',
#  'Kadoelen',
#  'Kinkerbuurt',
#  'Landlust',
#  'Lutkemeer/Ookmeer',
#  'Middelveldsche Akerpolder',
#  'Middenmeer',
#  'Museumkwartier',
#  'Nellestein',
#  'Nieuw-West',
#  'Nieuwe Pijp',
#  'Nieuwendammerdijk/Buiksloterdijk',
#  'Nieuwmarkt/Lastage',
#  'Noord',
#  'Noordelijke IJ-oevers-Oost',
#  'Noordelijke IJ-oevers-West',
#  'Oost',
#  'Oostelijk Havengebied',
#  'Oostelijke Eilanden/Kadijken',
#  'Oosterparkbuurt',
#  'Oostzanerwerf',
#  'Osdorp-Midden',
#  'Osdorp-Oost',
#  'Oude Pijp',
#  'Overtoomse Sluis',
#  'Overtoomse Veld',
#  'Prinses Irenebuurt e.o.',
#  'Rijnbuurt',
#  'Scheldebuurt',
#  'Schinkelbuurt',
#  'Sloter-/Riekerpolder',
#  'Sloterdijk',
#  'Slotermeer-Noordoost',
#  'Slotermeer-Zuidwest',
#  'Slotervaart-Noord',
#  'Slotervaart-Zuid',
#  'Spaarndammer- en Zeeheldenbuurt',
#  'Staatsliedenbuurt',
#  'Stadionbuurt',
#  'Transvaalbuurt',
#  'Tuindorp Buiksloot',
#  'Tuindorp Nieuwendam',
#  'Tuindorp Oostzaan',
#  'Van Galenbuurt',
#  'Van Lennepbuurt',
#  'Volewijck',
#  'Vondelbuurt',
#  'Waterland',
#  'Waterlandpleinbuurt',
#  'Weesperbuurt/Plantage',
#  'Weesperzijde',
#  'West',
#  'Westelijk Havengebied',
#  'Westindische Buurt',
#  'Westlandgracht',
#  'Westpoort',
#  'Willemspark',
#  'Zeeburgereiland/Nieuwe Diep',
#  'Zuid',
#  'Zuid-Pijp',
#  'Zuidas',
#  'Zuidoost']

# %%
# Merge data on post codes
houses = pd.merge(houses, post_wijken[['PC6','Wijknaam_2019K_NAAM']], how='left', left_on='post_code', right_on='PC6')

# %%
houses.isnull().sum()
# Out:
# Unnamed: 0                0
# Unnamed: 0.1              0
# price                     1
# post_code                 0
# neighborhood              0
# living_area               0
# rooms                     0
# year                      0
# offered_since            14
# status                   14
# monthly_cost_vve          0
# type                     14
# bedrooms                130
# bathrooms               484
# isolation               688
# energy_label           1038
# heating                 411
# parking                 539
# garage                  271
# balcony                 180
# garden                  183
# storage                 933
# location               2010
# loc                       0
# PC6                       4
# Wijknaam_2019K_NAAM       4
# dtype: int64

# %%
houses[houses['Wijknaam_2019K_NAAM'].isnull()]
# Out:
#       Unnamed: 0  Unnamed: 0.1     price post_code   neighborhood  \
# 1958        1958          1958  196000.0    1087VR  Centrumeiland
# 1959        1959          1959  445000.0    1087VR  Centrumeiland
# 1960        1960          1960  357000.0    1087VR  Centrumeiland
# 1961        1961          1961  241000.0    1087VR  Centrumeiland
#
#       living_area  rooms      year offered_since       status  ...  \
# 1958           46      1  20112020     3 maanden  Beschikbaar  ...
# 1959          107      4  20112020     3 maanden  Beschikbaar  ...
# 1960           86      3  20112020     3 maanden  Beschikbaar  ...
# 1961           58      2  20112020     3 maanden  Beschikbaar  ...
#
#                           heating parking  garage        balcony  \
# 1958  Stadsverwarming, Warmtepomp     NaN      Ja  Niet aanwezig
# 1959  Stadsverwarming, Warmtepomp     NaN      Ja  Niet aanwezig
# 1960  Stadsverwarming, Warmtepomp     NaN      Ja  Niet aanwezig
# 1961  Stadsverwarming, Warmtepomp     NaN      Ja  Niet aanwezig
#
#              garden   storage location         loc  PC6 Wijknaam_2019K_NAAM
# 1958  Niet aanwezig  Aanwezig      NaN  ['-', '-']  NaN                 NaN
# 1959  Niet aanwezig  Aanwezig      NaN  ['-', '-']  NaN                 NaN
# 1960  Niet aanwezig  Aanwezig      NaN  ['-', '-']  NaN                 NaN
# 1961  Niet aanwezig  Aanwezig      NaN  ['-', '-']  NaN                 NaN
#
# [4 rows x 26 columns]

# %%
# Adjust names that they match what is required for combining the income information (as we don't have post_code level data)
income.neighborhood = income.neighborhood.apply(lambda x: re.sub('-', ' ', x))
income.neighborhood = income.neighborhood.apply(lambda x: re.sub('De Omval/Overamstel', 'Omval/Overamstel', x))

# %%
houses = pd.merge(houses, income, how='left', left_on='Wijknaam_2019K_NAAM', right_on='neighborhood')

# %%
houses[houses['total'].isnull()]
# Out:
#       Unnamed: 0  Unnamed: 0.1     price post_code neighborhood_x  \
# 541          541           541  399000.0    1087VA  Centrumeiland
# 542          542           542  550000.0    1087VA  Centrumeiland
# 543          543           543  325000.0    1087VA  Centrumeiland
# 1890        1890          1890  675000.0    1087VA  Centrumeiland
# 1895        1895          1895  495000.0    1087VA  Centrumeiland
# 1896        1896          1896  540000.0    1087VA  Centrumeiland
# 1897        1897          1897  285000.0    1087VA  Centrumeiland
# 1958        1958          1958  196000.0    1087VR  Centrumeiland
# 1959        1959          1959  445000.0    1087VR  Centrumeiland
# 1960        1960          1960  357000.0    1087VR  Centrumeiland
# 1961        1961          1961  241000.0    1087VR  Centrumeiland
#
#       living_area  rooms      year offered_since       status  ...  \
# 541            81      3      2021       2 weken  Beschikbaar  ...
# 542           123      4      2021       2 weken  Beschikbaar  ...
# 543            64      2      2021       2 weken  Beschikbaar  ...
# 1890          150      5  20112020     3 maanden  Beschikbaar  ...
# 1895          105      4  20112020     2 maanden  Beschikbaar  ...
# 1896          120      6  20112020     2 maanden  Beschikbaar  ...
# 1897           60      3  20112020     2 maanden  Beschikbaar  ...
# 1958           46      1  20112020     3 maanden  Beschikbaar  ...
# 1959          107      4  20112020     3 maanden  Beschikbaar  ...
# 1960           86      3  20112020     3 maanden  Beschikbaar  ...
# 1961           58      2  20112020     3 maanden  Beschikbaar  ...
#
#                          loc     PC6  Wijknaam_2019K_NAAM  neighborhood_y  \
# 541   [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 542   [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 543   [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 1890  [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 1895  [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 1896  [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 1897  [52.3523901, 5.011545]  1087VA          IJburg Oost     IJburg Oost
# 1958              ['-', '-']     NaN                  NaN             NaN
# 1959              ['-', '-']     NaN                  NaN             NaN
# 1960              ['-', '-']     NaN                  NaN             NaN
# 1961              ['-', '-']     NaN                  NaN             NaN
#
#      income_low income_med_low income_med income_med_high ingome_high total
# 541         NaN            NaN        NaN             NaN         NaN   NaN
# 542         NaN            NaN        NaN             NaN         NaN   NaN
# 543         NaN            NaN        NaN             NaN         NaN   NaN
# 1890        NaN            NaN        NaN             NaN         NaN   NaN
# 1895        NaN            NaN        NaN             NaN         NaN   NaN
# 1896        NaN            NaN        NaN             NaN         NaN   NaN
# 1897        NaN            NaN        NaN             NaN         NaN   NaN
# 1958        NaN            NaN        NaN             NaN         NaN   NaN
# 1959        NaN            NaN        NaN             NaN         NaN   NaN
# 1960        NaN            NaN        NaN             NaN         NaN   NaN
# 1961        NaN            NaN        NaN             NaN         NaN   NaN
#
# [11 rows x 33 columns]

# %% [markdown]
# Some of the newer neighborhoods don't have information on these datasets. I will deal with null values at later stage in this project.

# %% [markdown]
# # Neighborhood info on Safety - Preparation

# %%
safety.head()
# Out:
#   VM14gebiednaam afgekort VM14gebiednummer  VM14 gebiedsnaam voluit  \
# 1                     A00                1    Burgwallen-Oude Zijde
# 2                     A01                2  Burgwallen-Nieuwe Zijde
# 3                     A02                3      Grachtengordel-West
# 4                     A03                4      Grachtengordel-Zuid
# 5                     A04                5               Nieuwmarkt
#
#   totale veiligheidsindex  \
# 1                   178.1
# 2                  168.84
# 3                   79.61
# 4                  137.45
# 5                  120.79
#
#   index gemiddelde inschatting (ontwikkeling) buurtcriminaliteit en -overlast  \
# 1                                             136.67
# 2                                             122.61
# 3                                             110.42
# 4                                             112.97
# 5                                             117.95
#
#   index gemiddelde score onveiligheids-gevoelens buurt  \
# 1                                              99.27
# 2                                              94.46
# 3                                              52.24
# 4                                               65.4
# 5                                               75.9
#
#   index gemiddelde score vermijding plekken en situaties in buurt  \
# 1                                              84.26
# 2                                              73.79
# 3                                              45.99
# 4                                              45.37
# 5                                              68.92
#
#   totale index onveiligheids-beleving deelindex overlast: personenoverlast  \
# 1                              106.73                               507.91
# 2                               96.95                               453.97
# 3                               69.55                               132.56
# 4                               74.58                                268.8
# 5                               87.59                               203.33
#
#   deelindex overlast: verloedering  ... populatie per 1-1-2017  \
# 1                           143.21  ...                   4293
# 2                            130.8  ...                   4130
# 3                           100.52  ...                   6374
# 4                           127.85  ...                   5383
# 5                           119.49  ...                   9676
#
#   aantal woningen per 1-1-2017 aantal winkels per  1-1-2017  \
# 1                         2917                          222
# 2                         2884                          594
# 3                         4314                          245
# 4                         3449                          177
# 5                         6190                          128
#
#   aantal bedrijven (niet-winkels) per  1-1-2017  aantal werkzame personen  \
# 1                                          1934                      6233
# 2                                          2350                      9428
# 3                                          3043                      6989
# 4                                          1799                      6350
# 5                                          2218                      6830
#
#   aantal studenten (VO, HBO en WO) aantal bezoekers op een gemiddelde dag  \
# 1                             1746                                  80626
# 2                             1689                                 139692
# 3                                0                                  43940
# 4                                0                                  29459
# 5                             2217                                  35470
#
#   som werkzame personen, studenten en bezoekers  \
# 1                                         88605
# 2                                        150809
# 3                                         50929
# 4                                         35809
# 5                                         44517
#
#   aantal verblijvers in een buurt waarbij nbezoek voor 1/3 meetelt  \
# 1                                              33828
# 2                                            54399.7
# 3                                            23350.3
# 4                                            17319.3
# 5                                              24515
#
#   aantal verblijvers in een buurt waarbij werkzame personen voor 1/3 en andere bezoekers voor 1/8 meetellen
# 1                                            16667.2
# 2                                            24945.3
# 3                                            14196.2
# 4                                              11182
# 5                                            16663.5
#
# [5 rows x 186 columns]

# %%
# Pick specific columns 
safety = safety[['VM14 gebiedsnaam voluit', 'totale veiligheidsindex', 'totale index onveiligheids-beleving', 'totale overlastindex', 'totale criminaliteitsindex', 'aantal winkels per  1-1-2017', 'aantal bedrijven (niet-winkels) per  1-1-2017', 'aantal bezoekers op een gemiddelde dag']]

# %%
safety
# Out:
#      VM14 gebiedsnaam voluit totale veiligheidsindex  \
# 1      Burgwallen-Oude Zijde                   178.1
# 2    Burgwallen-Nieuwe Zijde                  168.84
# 3        Grachtengordel-West                   79.61
# 4        Grachtengordel-Zuid                  137.45
# 5                 Nieuwmarkt                  120.79
# ..                       ...                     ...
# 137                De Kwakel                   43.03
# 138              Kudelstaart                   58.24
# 139       Aalsmeer  Hornmeer                   63.96
# 140            Aalsmeer Oost                   57.32
# 141    Aalsmeer Centrum/Zuid                   53.34
#
#     totale index onveiligheids-beleving totale overlastindex  \
# 1                                106.73               325.56
# 2                                 96.95               292.38
# 3                                 69.55               116.54
# 4                                 74.58               198.33
# 5                                 87.59               161.41
# ..                                  ...                  ...
# 137                                61.9                45.58
# 138                               84.37                60.93
# 139                               64.37                74.14
# 140                               74.79                60.76
# 141                               71.57                62.31
#
#     totale criminaliteitsindex aantal winkels per  1-1-2017  \
# 1                       102.01                          222
# 2                        117.2                          594
# 3                        52.74                          245
# 4                       139.46                          177
# 5                       113.35                          128
# ..                         ...                          ...
# 137                       21.6                           10
# 138                      29.42                           18
# 139                      53.36                            8
# 140                       36.4                           39
# 141                      26.16                           70
#
#     aantal bedrijven (niet-winkels) per  1-1-2017  \
# 1                                            1934
# 2                                            2350
# 3                                            3043
# 4                                            1799
# 5                                            2218
# ..                                            ...
# 137                                           499
# 138                                           454
# 139                                           340
# 140                                          1031
# 141                                           802
#
#     aantal bezoekers op een gemiddelde dag
# 1                                    80626
# 2                                   139692
# 3                                    43940
# 4                                    29459
# 5                                    35470
# ..                                     ...
# 137                                   1800
# 138                                   2245
# 139                                   1388
# 140                                   2776
# 141                                   8019
#
# [141 rows x 8 columns]

# %%
# Translate columns names
new_columns = ['buurt', 'safety_index', 'safety_perception_index', 'nuisance_index', 'crime_index', 'no_shops', 'no_companies', 'daily_visitors']

# %%
# Assign new column names
safety.columns = new_columns

# %%
safety.head()
# Out:
#                      buurt safety_index safety_perception_index  \
# 1    Burgwallen-Oude Zijde        178.1                  106.73
# 2  Burgwallen-Nieuwe Zijde       168.84                   96.95
# 3      Grachtengordel-West        79.61                   69.55
# 4      Grachtengordel-Zuid       137.45                   74.58
# 5               Nieuwmarkt       120.79                   87.59
#
#   nuisance_index crime_index no_shops no_companies daily_visitors
# 1         325.56      102.01      222         1934          80626
# 2         292.38       117.2      594         2350         139692
# 3         116.54       52.74      245         3043          43940
# 4         198.33      139.46      177         1799          29459
# 5         161.41      113.35      128         2218          35470

# %%
# Transform names to match our requested format
safety.buurt = safety.buurt.apply(lambda x: re.sub('-', ' ', x))

# %%
# Merge datasets together
houses = pd.merge(houses, safety, how='left', left_on='Wijknaam_2019K_NAAM', right_on='buurt')

# %%
houses.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'price', 'post_code', 'neighborhood_x',
#        'living_area', 'rooms', 'year', 'offered_since', 'status',
#        'monthly_cost_vve', 'type', 'bedrooms', 'bathrooms', 'isolation',
#        'energy_label', 'heating', 'parking', 'garage', 'balcony', 'garden',
#        'storage', 'location', 'loc', 'PC6', 'Wijknaam_2019K_NAAM',
#        'neighborhood_y', 'income_low', 'income_med_low', 'income_med',
#        'income_med_high', 'ingome_high', 'total', 'buurt', 'safety_index',
#        'safety_perception_index', 'nuisance_index', 'crime_index', 'no_shops',
#        'no_companies', 'daily_visitors'],
#       dtype='object')

# %%
houses.head()
# Out:
# 146                Houthavens
# 405     Westelijk Havengebied
# 544               IJburg Oost
# 545               IJburg Oost
# 546               IJburg Oost
# 1030               Houthavens
# 1117               Houthavens
# 1406               Houthavens
# 1655    Westelijk Havengebied
# 1724               Houthavens
# 1906              IJburg Oost
# 1911              IJburg Oost
# 1912              IJburg Oost
# 1913              IJburg Oost
# 1935               Houthavens
# 1976                      NaN
# 1977                      NaN
# 1978                      NaN
# 1979                      NaN
# Name: Wijknaam_2019K_NAAM, dtype: object

# %%
houses.drop(columns={'Unnamed: 0', 'Unnamed: 0.1', 'location', 'PC6', 'n'}),
# Out:
#    Unnamed: 0  Unnamed: 0.1      price post_code          neighborhood_x  \
# 0           0             0   550000.0    1055NL          Gibraltarbuurt
# 1           1             1   675000.0    1054GB    Vondelparkbuurt Oost
# 2           2             2  1000000.0    1075EG  Willemsparkbuurt Noord
# 3           3             3   475000.0    1064DD   Noordoever Sloterplas
# 4           4             4   485000.0    1016TA     Groenmarktkadebuurt
#
#    living_area  rooms  year offered_since       status  ... ingome_high total  \
# 0          100      4  1937    30-06-2020  Beschikbaar  ...    0.195946   1.0
# 1           88      4  1950    30-06-2020  Beschikbaar  ...    0.357143   1.0
# 2          109      4  1906    30-06-2020  Beschikbaar  ...    0.487179   1.0
# 3          107      4  1999    30-06-2020  Beschikbaar  ...     0.11194   1.0
# 4           71      3  1906    30-06-2020  Beschikbaar  ...    0.277108   1.0
#
#                  buurt  safety_index safety_perception_index nuisance_index  \
# 0             Landlust        107.58                   98.26         129.33
# 1          Vondelbuurt         95.98                   73.36         106.85
# 2          Willemspark          76.5                   72.79          74.59
# 3  Slotermeer Zuidwest        128.64                  122.43         138.62
# 4              Jordaan         92.96                   71.03         130.83
#
#   crime_index no_shops no_companies daily_visitors
# 0       95.15       67         2791           6219
# 1      107.73       76         2022           8159
# 2       82.13       31         1263           3225
# 3      124.88        7          525           3365
# 4       77.02      270         4004          31695
#
# [5 rows x 41 columns]

# %%
# Save dataset for next stage
houses.to_csv('final_houses.csv')
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'price', 'post_code', 'neighborhood_x',
#        'living_area', 'rooms', 'year', 'offered_since', 'status',
#        'monthly_cost_vve', 'type', 'bedrooms', 'bathrooms', 'isolation',
#        'energy_label', 'heating', 'parking', 'garage', 'balcony', 'garden',
#        'storage', 'location', 'loc', 'PC6', 'Wijknaam_2019K_NAAM',
#        'neighborhood_y', 'income_low', 'income_med_low', 'income_med',
#        'income_med_high', 'ingome_high', 'total', 'buurt', 'safety_index',
#        'safety_perception_index', 'nuisance_index', 'crime_index', 'no_shops',
#        'no_companies', 'daily_visitors'],
#       dtype='object')
